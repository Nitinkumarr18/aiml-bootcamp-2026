# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[10,20,15,30,25]
plt.plot(x,y)
plt.title("Line chart")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %%
x='10'
y='5'
print(x+y)
# Out:
# 105

# %%
mark1=78
mark2=85
mark3=92

mark=[78,85,92]

mark.append(95)

print(len(mark))
print(max(mark))
print(min(mark))
# Out:
# 4
# 95
# 78

# %%
stud=['ayush',88,True]
student={
    "name":"Ayush",
    "mark":88,
    "enrolled":True
}
print(student["name"])
print(student["mark"])
print(student["enrolled"])
# Out:
# Ayush
# 88
# True
